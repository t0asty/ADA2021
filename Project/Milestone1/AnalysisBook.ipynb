# %%
import pandas as pd

# %%
quotes = pd.read_json('./quotes-2019-nytimes.json', orient='records', lines=True)

# %%
quotes.head()
# Out:
#              quoteID                                          quotation  \
# 0  2019-04-17-024782                It is not a low-income immigration,
# 1  2019-04-02-001128  a champion figure skater switching to roller s...
# 2  2019-05-09-055187  It makes it much more difficult for him to mak...
# 3  2019-10-31-056366                       It puts me in a predicament,
# 4  2019-01-04-001792                                  A Pile of Leaves.
#
#           speaker                                               qids  \
# 0    James Fisher  [Q16213953, Q20707104, Q43143598, Q58886302, Q...
# 1     John Updike                                          [Q105756]
# 2            None                                                 []
# 3  Xavier Becerra                                         [Q1855840]
# 4            None                                                 []
#
#                  date  numOccurrences  \
# 0 2019-04-17 13:31:18               1
# ...

# %%
quotes.shape
# Out:
# (207527, 9)

# %%
quotes.describe()
# Out:
#        numOccurrences
# count   207527.000000
# mean         7.698844
# std         55.648115
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max      12095.000000

# %%
quotes.sort_values(by='numOccurrences', ascending=False).head()
# Out:
#                   quoteID                                          quotation  \
# 21764   2019-04-12-080259          Star... [ + ] Wars: The Rise of Skywalker
# 19369   2019-09-20-084768  The president must be held accountable -- no o...
# 109000  2019-07-26-013259          Fight for Freedom. Stand with Hong Kong!!
# 182596  2019-03-01-125356                              When They See Us.....
# 197409  2019-01-29-100043                            THIS IS MAGA COUNTRY!!!
#
#                 speaker        qids                date  numOccurrences  \
# 21764              None          [] 2019-04-12 00:00:00           12095
# 19369              None          [] 2019-09-20 00:00:00            4538
# 109000      Daryl Morey  [Q5226214] 2019-07-26 17:32:18            3888
# 182596             None          [] 2019-03-01 15:21:56            3766
# 197409  Jussie Smollett  [Q6315685] 2019-01-29 00:00:00            3519
#
#                                                    probas  \
# ...
